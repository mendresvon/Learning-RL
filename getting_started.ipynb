# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip install "stable-baselines3[extra]"
# Out:
# Requirement already satisfied: stable-baselines3[extra] in ./.venv/lib/python3.13/site-packages (2.9.0)
# Requirement already satisfied: gymnasium<2.0,>=0.29.1 in ./.venv/lib/python3.13/site-packages (from stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in ./.venv/lib/python3.13/site-packages (from stable-baselines3[extra]) (2.5.0)
# Requirement already satisfied: torch<3.0,>=2.8 in ./.venv/lib/python3.13/site-packages (from stable-baselines3[extra]) (2.12.1)
# Requirement already satisfied: cloudpickle in ./.venv/lib/python3.13/site-packages (from stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: opencv-python in ./.venv/lib/python3.13/site-packages (from stable-baselines3[extra]) (4.13.0.92)
# Requirement already satisfied: pygame-ce in ./.venv/lib/python3.13/site-packages (from stable-baselines3[extra]) (2.5.7)
# Requirement already satisfied: tensorboard>=2.9.1 in ./.venv/lib/python3.13/site-packages (from stable-baselines3[extra]) (2.21.0)
# Requirement already satisfied: psutil in ./.venv/lib/python3.13/site-packages (from stable-baselines3[extra]) (7.2.2)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.13/site-packages (from stable-baselines3[extra]) (4.68.3)
# Requirement already satisfied: rich in ./.venv/lib/python3.13/site-packages (from stable-baselines3[extra]) (15.0.0)
# Requirement already satisfied: ale-py>=0.9.0 in ./.venv/lib/python3.13/site-packages (from stable-baselines3[extra]) (0.12.0)
# Requirement already satisfied: pillow in ./.venv/lib/python3.13/site-packages (from stable-baselines3[extra]) (12.2.0)
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (from stable-baselines3[extra]) (3.0.3)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.13/site-packages (from stable-baselines3[extra]) (3.11.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in ./.venv/lib/python3.13/site-packages (from gymnasium<2.0,>=0.29.1->stable-baselines3[extra]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in ./.venv/lib/python3.13/site-packages (from gymnasium<2.0,>=0.29.1->stable-baselines3[extra]) (0.0.6)
# Requirement already satisfied: filelock in ./.venv/lib/python3.13/site-packages (from torch<3.0,>=2.8->stable-baselines3[extra]) (3.29.4)
# Requirement already satisfied: setuptools<82 in ./.venv/lib/python3.13/site-packages (from torch<3.0,>=2.8->stable-baselines3[extra]) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in ./.venv/lib/python3.13/site-packages (from torch<3.0,>=2.8->stable-baselines3[extra]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in ./.venv/lib/python3.13/site-packages (from torch<3.0,>=2.8->stable-baselines3[extra]) (3.6.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.13/site-packages (from torch<3.0,>=2.8->stable-baselines3[extra]) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in ./.venv/lib/python3.13/site-packages (from torch<3.0,>=2.8->stable-baselines3[extra]) (2026.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.13/site-packages (from sympy>=1.13.3->torch<3.0,>=2.8->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in ./.venv/lib/python3.13/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.74.0 in ./.venv/lib/python3.13/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.81.1)
# Requirement already satisfied: markdown>=2.6.8 in ./.venv/lib/python3.13/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.10.2)
# Requirement already satisfied: packaging in ./.venv/lib/python3.13/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in ./.venv/lib/python3.13/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (7.35.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.13/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.13/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in ./.venv/lib/python3.13/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.13/site-packages (from matplotlib->stable-baselines3[extra]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.13/site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.13/site-packages (from matplotlib->stable-baselines3[extra]) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.13/site-packages (from matplotlib->stable-baselines3[extra]) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.13/site-packages (from matplotlib->stable-baselines3[extra]) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.13/site-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.13/site-packages (from rich->stable-baselines3[extra]) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.13/site-packages (from rich->stable-baselines3[extra]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)

# %%
import os
import gymnasium as gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Load Environment

# %%
environment_name = 'CartPole-v0'
env = gym.make(environment_name)
# Out:
# /Users/breznev/Documents/Learning/Reinforcement Learning/.venv/lib/python3.13/site-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(

# %%
environment_name
# Out:
# 'CartPole-v0'

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        score += reward
    print(f'Episode{episode} Score{score}')
# Out:
# Episode1 Score27.0
# Episode2 Score34.0
# Episode3 Score19.0
# Episode4 Score43.0
# Episode5 Score25.0
# /Users/breznev/Documents/Learning/Reinforcement Learning/.venv/lib/python3.13/site-packages/gymnasium/envs/classic_control/cartpole.py:251: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("CartPole-v0", render_mode="rgb_array")
#   gym.logger.warn(

# %%
env.reset()
# Out:
# (array([ 0.00471968,  0.03868198,  0.01004755, -0.00428003], dtype=float32),
#  {})

# %%
episodes = 5
for episode in range(1, episodes+1):
    print(episode)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # 3.
